# %% [markdown]
# # hypothesis 3-1
# ------------------------------------------------------------------------
# 1. VGG19 사용
# 2. fine-tuning 시, 배치정규화와 리키렐루를 사용한다. 드랍아웃도 0.4로 설정한다.
# 3. imageGenerating시 옵션을 많이 사용하지 않는다. 그냥 1.2확대-0.1좌우이동 정도만 사용한다.
# 4. 이미지 size는 pixel(180,180,3)으로 설정한다. 224로 설정해도 정확도는 올라가지 않는다.
# 5. lr = 0.0001로 설정한다. 아담 최적화를 사용하므로 0.0001로 학습률을  설정해도 될 듯하다.

# %% [markdown]
# # hypothesis 3-2
# -----------------------------------------------------------------------------------------------------------------
# 1. lr=0.001로 학습진행, pixel size를 (100,100,3)으로 둔다.

# %% [markdown]
# # hypothesis 3-10
# ------------
# 1. (150, 150)세팅, fine_tuning layer노드 개수를 512개에서 150개로 줄임.
# 2. 오버피팅의 조짐이 보인다..

# %%
# %matplotlib inline
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pydot

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import Input, models, layers, optimizers, metrics, regularizers
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization, LeakyReLU, Dropout, Activation, Conv2D, MaxPooling2D
from tensorflow.keras.applications import VGG19
#from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import plot_model

# %%
np.random.seed(3)
tf.compat.v1.set_random_seed(3)

train_datagen = ImageDataGenerator(rescale=1./255,
                                  horizontal_flip=True,
                                  width_shift_range=0.1,
                                  height_shift_range=0.1,
                                  rotation_range=5,
                                  shear_range=0.7,
                                  zoom_range=[0.9, 1.2],
                                  #vertical_flip=True,
                                  fill_mode='nearest')

train_generator = train_datagen.flow_from_directory(
       './Data/Train/',
       target_size=(150, 150),
       batch_size=5,
       class_mode="sparse")

validation_datagen = ImageDataGenerator(rescale=1./255)

validation_generator = validation_datagen.flow_from_directory(
       './Data/Validation/',
       target_size=(150, 150), #어제는 100으로 뒀을 때 제제제이이이ㅣ이리리일잘나옴
       batch_size=5,
       class_mode="sparse")


transfer_model = VGG19(weights='imagenet', include_top=False, input_shape=(150, 150, 3))
transfer_model.trainable = False
transfer_model.summary()

finetune_model = models.Sequential()
finetune_model.add(transfer_model)
finetune_model.add(Flatten())
finetune_model.add(BatchNormalization())
finetune_model.add(Dense (128, activation='relu'))
finetune_model.add(Dropout(0.3))
finetune_model.add(Dense(5, activation='softmax'))
finetune_model.summary()

finetune_model.compile(loss='sparse_categorical_crossentropy', 
                       #optimizer=optimizers.SGD(lr=1E-5, momentum=0.9, nesterov=True),
                       optimizer=optimizers.Adam(learning_rate=0.00001),
                       metrics=['accuracy'])

history = finetune_model.fit_generator(
       train_generator,
       steps_per_epoch=100,
       epochs=120,  #자기전에 100번 돌려보자..
       validation_data=validation_generator,
       validation_steps=4)

finetune_model.save('HCF_classification_3_0614_pm10.h5')
plot_model(finetune_model, to_file='model10.png')
plot_model(finetune_model, to_file='model_shapes10.png', show_shapes=True)
# Out:
# Found 325 images belonging to 5 classes.
# Found 139 images belonging to 5 classes.
# WARNING:tensorflow:From C:\Users\WIN10\Anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# =================================================================
# Total params: 20,024,384
# Trainable params: 0
# Non-trainable params: 20,024,384
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg19 (Model)                (None, 4, 4, 512)         20024384
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 8192)              32768
# _________________________________________________________________
# dense (Dense)                (None, 128)               1048704
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 645
# =================================================================
# Total params: 21,106,501
# Trainable params: 1,065,733
# Non-trainable params: 20,040,768
# _________________________________________________________________
# Epoch 1/120
# 100/100 [==============================] - 104s 1s/step - loss: 2.0259 - acc: 0.2440 - val_loss: 1.4978 - val_acc: 0.2500
# Epoch 2/120
# 100/100 [==============================] - 103s 1s/step - loss: 1.7657 - acc: 0.3200 - val_loss: 1.4291 - val_acc: 0.3500
# Epoch 3/120
# 100/100 [==============================] - 110s 1s/step - loss: 1.5524 - acc: 0.3900 - val_loss: 1.3643 - val_acc: 0.4500
# Epoch 4/120
# 100/100 [==============================] - 105s 1s/step - loss: 1.4255 - acc: 0.4380 - val_loss: 1.3149 - val_acc: 0.5000
# Epoch 5/120
# 100/100 [==============================] - 103s 1s/step - loss: 1.4128 - acc: 0.4440 - val_loss: 1.2376 - val_acc: 0.4500
# Epoch 6/120
# 100/100 [==============================] - 103s 1s/step - loss: 1.2635 - acc: 0.4980 - val_loss: 1.2110 - val_acc: 0.5000
# Epoch 7/120
# 100/100 [==============================] - 103s 1s/step - loss: 1.2176 - acc: 0.5360 - val_loss: 1.1684 - val_acc: 0.5000
# Epoch 8/120
# 100/100 [==============================] - 103s 1s/step - loss: 1.1523 - acc: 0.5360 - val_loss: 1.0987 - val_acc: 0.5500
# Epoch 9/120
# 100/100 [==============================] - 104s 1s/step - loss: 1.0734 - acc: 0.5760 - val_loss: 1.0677 - val_acc: 0.6500
# Epoch 10/120
# 100/100 [==============================] - 103s 1s/step - loss: 1.0650 - acc: 0.5760 - val_loss: 1.0452 - val_acc: 0.6500
# Epoch 11/120
# 100/100 [==============================] - 103s 1s/step - loss: 0.9980 - acc: 0.6160 - val_loss: 1.0162 - val_acc: 0.6500
# Epoch 12/120
# 100/100 [==============================] - 103s 1s/step - loss: 0.9609 - acc: 0.6420 - val_loss: 1.0211 - val_acc: 0.7000
# Epoch 13/120
# 100/100 [==============================] - 104s 1s/step - loss: 0.8868 - acc: 0.6840 - val_loss: 1.0052 - val_acc: 0.7000
# Epoch 14/120
# 100/100 [==============================] - 104s 1s/step - loss: 0.8832 - acc: 0.6600 - val_loss: 1.0114 - val_acc: 0.7500
# Epoch 15/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.8918 - acc: 0.6300 - val_loss: 1.0073 - val_acc: 0.7500
# Epoch 16/120
# 100/100 [==============================] - 104s 1s/step - loss: 0.8350 - acc: 0.6840 - val_loss: 0.9940 - val_acc: 0.7500
# Epoch 17/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.7995 - acc: 0.6980 - val_loss: 0.9506 - val_acc: 0.7500
# Epoch 18/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.7553 - acc: 0.7280 - val_loss: 0.9598 - val_acc: 0.7500
# Epoch 19/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.7745 - acc: 0.7260 - val_loss: 0.9771 - val_acc: 0.7500
# Epoch 20/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.7893 - acc: 0.7220 - val_loss: 0.9224 - val_acc: 0.7500
# Epoch 21/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.7788 - acc: 0.7180 - val_loss: 0.9341 - val_acc: 0.7500
# Epoch 22/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.6678 - acc: 0.7540 - val_loss: 0.9384 - val_acc: 0.7500
# Epoch 23/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.6693 - acc: 0.7420 - val_loss: 0.8959 - val_acc: 0.7500
# Epoch 24/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.6391 - acc: 0.7700 - val_loss: 0.8820 - val_acc: 0.7000
# Epoch 25/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.6691 - acc: 0.7440 - val_loss: 0.8498 - val_acc: 0.7500
# Epoch 26/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.6163 - acc: 0.7920 - val_loss: 0.8347 - val_acc: 0.7500
# Epoch 27/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.5951 - acc: 0.7960 - val_loss: 0.8469 - val_acc: 0.7500
# Epoch 28/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.6312 - acc: 0.7600 - val_loss: 0.8356 - val_acc: 0.8000
# Epoch 29/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.5133 - acc: 0.8380 - val_loss: 0.8312 - val_acc: 0.7500
# Epoch 30/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.5627 - acc: 0.7960 - val_loss: 0.8020 - val_acc: 0.8000
# Epoch 31/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.5721 - acc: 0.8060 - val_loss: 0.8418 - val_acc: 0.7000
# Epoch 32/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.5443 - acc: 0.8120 - val_loss: 0.8308 - val_acc: 0.7000
# Epoch 33/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.5536 - acc: 0.8060 - val_loss: 0.8424 - val_acc: 0.7000
# Epoch 34/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.5254 - acc: 0.8120 - val_loss: 0.8278 - val_acc: 0.7000
# Epoch 35/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.5210 - acc: 0.8380 - val_loss: 0.8185 - val_acc: 0.7000
# Epoch 36/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.4801 - acc: 0.8440 - val_loss: 0.7943 - val_acc: 0.7000
# Epoch 37/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.4390 - acc: 0.8540 - val_loss: 0.7786 - val_acc: 0.7500
# Epoch 38/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.4129 - acc: 0.8740 - val_loss: 0.7686 - val_acc: 0.7500
# Epoch 39/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.4563 - acc: 0.8300 - val_loss: 0.7779 - val_acc: 0.7500
# Epoch 40/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.5056 - acc: 0.8120 - val_loss: 0.7493 - val_acc: 0.8000
# Epoch 41/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.4749 - acc: 0.8380 - val_loss: 0.7485 - val_acc: 0.7500
# Epoch 42/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.4599 - acc: 0.8420 - val_loss: 0.7346 - val_acc: 0.7500
# Epoch 43/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.4192 - acc: 0.8520 - val_loss: 0.7579 - val_acc: 0.7500
# Epoch 44/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.4341 - acc: 0.8580 - val_loss: 0.7599 - val_acc: 0.7000
# Epoch 45/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.4187 - acc: 0.8600 - val_loss: 0.7292 - val_acc: 0.7500
# Epoch 46/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.4450 - acc: 0.8500 - val_loss: 0.7447 - val_acc: 0.7500
# Epoch 47/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.4322 - acc: 0.8560 - val_loss: 0.7274 - val_acc: 0.7500
# Epoch 48/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.4164 - acc: 0.8500 - val_loss: 0.7244 - val_acc: 0.7500
# Epoch 49/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.4072 - acc: 0.8640 - val_loss: 0.7536 - val_acc: 0.7000
# Epoch 50/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.4064 - acc: 0.8520 - val_loss: 0.7422 - val_acc: 0.7500
# Epoch 51/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.3570 - acc: 0.8940 - val_loss: 0.7407 - val_acc: 0.7500
# Epoch 52/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.3563 - acc: 0.8920 - val_loss: 0.7635 - val_acc: 0.6500
# Epoch 53/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.4327 - acc: 0.8520 - val_loss: 0.7244 - val_acc: 0.7500
# Epoch 54/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.3868 - acc: 0.8780 - val_loss: 0.7503 - val_acc: 0.7000
# Epoch 55/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.3552 - acc: 0.8920 - val_loss: 0.7424 - val_acc: 0.7500
# Epoch 56/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.3972 - acc: 0.8820 - val_loss: 0.7271 - val_acc: 0.7000
# Epoch 57/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.3434 - acc: 0.8800 - val_loss: 0.7365 - val_acc: 0.7000
# Epoch 58/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.3513 - acc: 0.8860 - val_loss: 0.7334 - val_acc: 0.7000
# Epoch 59/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.3715 - acc: 0.8760 - val_loss: 0.7562 - val_acc: 0.6500
# Epoch 60/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.3532 - acc: 0.8780 - val_loss: 0.7202 - val_acc: 0.6500
# Epoch 61/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.3784 - acc: 0.8860 - val_loss: 0.7078 - val_acc: 0.7500
# Epoch 62/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.3430 - acc: 0.8900 - val_loss: 0.6833 - val_acc: 0.7500
# Epoch 63/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.3127 - acc: 0.9140 - val_loss: 0.7014 - val_acc: 0.7500
# Epoch 64/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.3406 - acc: 0.8960 - val_loss: 0.6875 - val_acc: 0.8000
# Epoch 65/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.3013 - acc: 0.8960 - val_loss: 0.7001 - val_acc: 0.7500
# Epoch 66/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.2989 - acc: 0.9100 - val_loss: 0.6860 - val_acc: 0.7000
# Epoch 67/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.2972 - acc: 0.9220 - val_loss: 0.6964 - val_acc: 0.7000
# Epoch 68/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.3110 - acc: 0.8960 - val_loss: 0.7013 - val_acc: 0.7500
# Epoch 69/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.3449 - acc: 0.8980 - val_loss: 0.6852 - val_acc: 0.7500
# Epoch 70/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.3009 - acc: 0.9140 - val_loss: 0.6808 - val_acc: 0.7000
# Epoch 71/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.2786 - acc: 0.9080 - val_loss: 0.6990 - val_acc: 0.7000
# Epoch 72/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.2842 - acc: 0.9260 - val_loss: 0.6797 - val_acc: 0.7500
# Epoch 73/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.2709 - acc: 0.9160 - val_loss: 0.7126 - val_acc: 0.7500
# Epoch 74/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.2966 - acc: 0.9180 - val_loss: 0.6886 - val_acc: 0.7500
# Epoch 75/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.3073 - acc: 0.9000 - val_loss: 0.7123 - val_acc: 0.7500
# Epoch 76/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.2675 - acc: 0.9160 - val_loss: 0.6835 - val_acc: 0.7500
# Epoch 77/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.2826 - acc: 0.9100 - val_loss: 0.6810 - val_acc: 0.8000
# Epoch 78/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.2718 - acc: 0.9120 - val_loss: 0.6595 - val_acc: 0.8000
# Epoch 79/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.2682 - acc: 0.9180 - val_loss: 0.6843 - val_acc: 0.7500
# Epoch 80/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.2555 - acc: 0.9020 - val_loss: 0.6891 - val_acc: 0.7500
# Epoch 81/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.2523 - acc: 0.9160 - val_loss: 0.6601 - val_acc: 0.8000
# Epoch 82/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.2390 - acc: 0.9240 - val_loss: 0.6399 - val_acc: 0.7500
# Epoch 83/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.2513 - acc: 0.9420 - val_loss: 0.6491 - val_acc: 0.7500
# Epoch 84/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.2818 - acc: 0.9040 - val_loss: 0.6431 - val_acc: 0.8500
# Epoch 85/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.2064 - acc: 0.9480 - val_loss: 0.6256 - val_acc: 0.8000
# Epoch 86/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.2614 - acc: 0.9280 - val_loss: 0.6135 - val_acc: 0.8000
# Epoch 87/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.2109 - acc: 0.9400 - val_loss: 0.6102 - val_acc: 0.8000
# Epoch 88/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.2264 - acc: 0.9340 - val_loss: 0.6124 - val_acc: 0.8000
# Epoch 89/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.2181 - acc: 0.9420 - val_loss: 0.6371 - val_acc: 0.8500
# Epoch 90/120
# 100/100 [==============================] - 103s 1s/step - loss: 0.2296 - acc: 0.9360 - val_loss: 0.6558 - val_acc: 0.8000
# Epoch 91/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.2383 - acc: 0.9360 - val_loss: 0.6331 - val_acc: 0.8000
# Epoch 92/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.2331 - acc: 0.9300 - val_loss: 0.6218 - val_acc: 0.8000
# Epoch 93/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.2024 - acc: 0.9380 - val_loss: 0.6428 - val_acc: 0.8000
# Epoch 94/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.2217 - acc: 0.9360 - val_loss: 0.6554 - val_acc: 0.8000
# Epoch 95/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.2663 - acc: 0.9060 - val_loss: 0.6418 - val_acc: 0.7500
# Epoch 96/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.2239 - acc: 0.9320 - val_loss: 0.6396 - val_acc: 0.8000
# Epoch 97/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.2274 - acc: 0.9260 - val_loss: 0.6250 - val_acc: 0.8000
# Epoch 98/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.2155 - acc: 0.9360 - val_loss: 0.6430 - val_acc: 0.8000
# Epoch 99/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.1693 - acc: 0.9500 - val_loss: 0.6459 - val_acc: 0.8000
# Epoch 100/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.1996 - acc: 0.9520 - val_loss: 0.6514 - val_acc: 0.8000
# Epoch 101/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.2316 - acc: 0.9200 - val_loss: 0.6424 - val_acc: 0.8000
# Epoch 102/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.1830 - acc: 0.9600 - val_loss: 0.6169 - val_acc: 0.8000
# Epoch 103/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.2207 - acc: 0.9380 - val_loss: 0.6818 - val_acc: 0.7500
# Epoch 104/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.1786 - acc: 0.9500 - val_loss: 0.6525 - val_acc: 0.8000
# Epoch 105/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.2040 - acc: 0.9300 - val_loss: 0.6223 - val_acc: 0.8000
# Epoch 106/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.1815 - acc: 0.9540 - val_loss: 0.6113 - val_acc: 0.8000
# Epoch 107/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.1663 - acc: 0.9540 - val_loss: 0.6123 - val_acc: 0.8000
# Epoch 108/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.2142 - acc: 0.9280 - val_loss: 0.5927 - val_acc: 0.8000
# Epoch 109/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.1931 - acc: 0.9420 - val_loss: 0.5814 - val_acc: 0.8500
# Epoch 110/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.1741 - acc: 0.9440 - val_loss: 0.5981 - val_acc: 0.8000
# Epoch 111/120
# 100/100 [==============================] - 104s 1s/step - loss: 0.1620 - acc: 0.9640 - val_loss: 0.6113 - val_acc: 0.8000
# Epoch 112/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.1870 - acc: 0.9500 - val_loss: 0.6018 - val_acc: 0.8000
# Epoch 113/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.2105 - acc: 0.9360 - val_loss: 0.5715 - val_acc: 0.8000
# Epoch 114/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.1592 - acc: 0.9600 - val_loss: 0.5759 - val_acc: 0.8000
# Epoch 115/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.1735 - acc: 0.9580 - val_loss: 0.5666 - val_acc: 0.8500
# Epoch 116/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.1768 - acc: 0.9500 - val_loss: 0.5785 - val_acc: 0.8000
# Epoch 117/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.1646 - acc: 0.9560 - val_loss: 0.5940 - val_acc: 0.8000
# Epoch 118/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.1763 - acc: 0.9480 - val_loss: 0.5931 - val_acc: 0.8000
# Epoch 119/120
# 100/100 [==============================] - 102s 1s/step - loss: 0.1825 - acc: 0.9420 - val_loss: 0.6062 - val_acc: 0.8000
# Epoch 120/120
# 100/100 [==============================] - 101s 1s/step - loss: 0.1726 - acc: 0.9480 - val_loss: 0.5719 - val_acc: 0.8000

# %%
acc= history.history['acc']
val_acc= history.history['val_acc']
y_vloss = history.history['val_loss']
y_loss = history.history['loss']

# 그래프로 표현
x_len = np.arange(len(y_loss))
plt.plot(x_len, acc, marker='.', c="red", label='Trainset_acc')
plt.plot(x_len, val_acc, marker='.', c="lightcoral", label='Testset_acc')

#x_len_2 = np.arange(len(acc))
#plt.plot(x_len, y_vloss, marker='.', c="cornflowerblue", label='Testset_loss')
#plt.plot(x_len, y_loss, marker='.', c="blue", label='Trainset_loss')

# 그래프에 그리드를 주고 레이블을 표시
plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss/acc')
plt.show()

# %%
x_len_2 = np.arange(len(acc))
plt.plot(x_len, y_vloss, marker='.', c="cornflowerblue", label='Testset_loss')
plt.plot(x_len, y_loss, marker='.', c="blue", label='Trainset_loss')

# 그래프에 그리드를 주고 레이블을 표시
plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss/acc')
plt.show()

# %%
import os
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

model = load_model('HCF_classification_3_0614_pm10.h5')
print(model.summary())

test_datagen = ImageDataGenerator(rescale=1./255) #이미지를 0에서 1사이의 값으로 만들어줌
test_generator = test_datagen.flow_from_directory(
        './Data/Test/',
        target_size=(150, 150),
        class_mode='sparse',
        batch_size=1,
        shuffle=False)
test_loss, test_acc = model.evaluate_generator(test_generator, steps = 85)

print("test_acc:", test_acc)

probabilities = model.predict_generator(test_generator,85)
print("acc_matrix_size:", np.array(probabilities).shape)
print("test_Set_filesize:", len(test_generator.filenames))

#print (probabilities)
#print()
for i in range(len(test_generator.filenames)):
    print(probabilities[i]," : " ,test_generator.filenames[i])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg19 (Model)                (None, 4, 4, 512)         20024384
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 8192)              32768
# _________________________________________________________________
# dense (Dense)                (None, 128)               1048704
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 645
# =================================================================
# Total params: 21,106,501
# Trainable params: 1,065,733
# Non-trainable params: 20,040,768
# _________________________________________________________________
# None
# Found 85 images belonging to 5 classes.
# test_acc: 0.8352941
# acc_matrix_size: (85, 5)
# test_Set_filesize: 85
# [1.0267828e-03 9.6683472e-01 3.1548817e-02 5.2878674e-04 6.0879298e-05]  :  0 jeyuk-bokkeum\제육볶음031.jpg
# [9.6832395e-01 3.0915871e-02 3.1774500e-04 3.1829849e-04 1.2408222e-04]  :  0 jeyuk-bokkeum\제육볶음032.jpg
# [9.9108785e-01 8.8919541e-03 5.2499931e-06 1.1121541e-05 3.7264579e-06]  :  0 jeyuk-bokkeum\제육볶음033.jpg
# [9.1981226e-01 6.4736426e-02 1.3029853e-02 2.2638903e-03 1.5741031e-04]  :  0 jeyuk-bokkeum\제육볶음034.jpg
# [9.4313049e-01 5.6642410e-03 5.0732937e-02 3.7691914e-04 9.5411844e-05]  :  0 jeyuk-bokkeum\제육볶음035.jpg
# [0.87498415 0.04278826 0.04511112 0.03372001 0.00339638]  :  0 jeyuk-bokkeum\제육볶음036.jpg
# [0.56655514 0.05352492 0.0059935  0.00120651 0.37271988]  :  0 jeyuk-bokkeum\제육볶음037.jpg
# [9.9546671e-01 1.3237170e-04 4.3786061e-03 2.0663747e-05 1.7145321e-06]  :  0 jeyuk-bokkeum\제육볶음038.jpg
# [1.65816903e-01 7.26587296e-01 2.41276823e-04 1.07199736e-01
#  1.54775422e-04]  :  0 jeyuk-bokkeum\제육볶음039.jpg
# [6.6050068e-02 9.1591096e-01 1.5952883e-02 1.3065273e-03 7.7952346e-04]  :  0 jeyuk-bokkeum\제육볶음040.jpg
# [2.7065927e-01 5.0620270e-01 2.2236021e-01 7.7055220e-04 7.3086512e-06]  :  0 jeyuk-bokkeum\제육볶음041.jpg
# [9.9912268e-01 7.1209040e-04 8.4401763e-05 3.1034073e-05 4.9768554e-05]  :  0 jeyuk-bokkeum\제육볶음042.jpg
# [9.9296486e-01 1.7934236e-03 5.1795025e-03 3.4521388e-05 2.7741016e-05]  :  0 jeyuk-bokkeum\제육볶음046.jpg
# [9.8770624e-01 1.2694256e-04 1.1076537e-02 9.0147497e-04 1.8890609e-04]  :  0 jeyuk-bokkeum\제육볶음047.jpg
# [9.0773618e-01 9.2033364e-02 2.0778603e-04 2.2179551e-05 5.1359035e-07]  :  0 jeyuk-bokkeum\제육볶음048.jpg
# [9.7546965e-01 1.6803341e-02 5.7440139e-03 8.3398743e-04 1.1489582e-03]  :  0 jeyuk-bokkeum\제육볶음049.jpg
# [9.5870847e-01 4.0970296e-02 2.0667262e-04 2.5084248e-06 1.1214830e-04]  :  0 jeyuk-bokkeum\제육볶음050.jpg
# [1.5031559e-02 1.3493691e-02 9.7099417e-01 4.6871125e-04 1.1851135e-05]  :  0 jeyuk-bokkeum\제육볶음054.jpg
# [0.03074623 0.75681335 0.19111294 0.00660706 0.01472036]  :  0 jeyuk-bokkeum\제육볶음055.jpg
# [9.9747914e-01 1.6556119e-03 2.4705967e-05 1.8932256e-04 6.5126637e-04]  :  0 jeyuk-bokkeum\제육볶음056.jpg
# [0.11682836 0.5796184  0.19610731 0.08823166 0.01921424]  :  1 jjajiangmian\짜장면001.jpg
# [4.1024438e-03 9.9419808e-01 9.8678947e-04 4.7532597e-04 2.3730141e-04]  :  1 jjajiangmian\짜장면002.jpg
# [5.5605571e-05 9.9989676e-01 4.3609863e-05 3.1826660e-06 7.4358815e-07]  :  1 jjajiangmian\짜장면031.jpg
# [1.1590687e-04 9.9970883e-01 4.9788210e-05 4.2678589e-06 1.2113966e-04]  :  1 jjajiangmian\짜장면032.jpg
# [1.25421475e-05 9.98268962e-01 1.67012604e-05 1.01206626e-03
#  6.89763285e-04]  :  1 jjajiangmian\짜장면033.jpg
# [7.4619439e-04 9.9874371e-01 5.3153010e-05 4.2414293e-04 3.2826320e-05]  :  1 jjajiangmian\짜장면034.jpg
# [2.8420673e-05 9.9967062e-01 1.7106858e-04 9.2831935e-05 3.7129106e-05]  :  1 jjajiangmian\짜장면035.jpg
# [1.1110222e-05 9.9992681e-01 9.9228000e-06 4.9250302e-05 2.9850473e-06]  :  1 jjajiangmian\짜장면036.jpg
# [2.9486083e-04 9.9903750e-01 3.2580865e-04 2.7116228e-04 7.0669077e-05]  :  1 jjajiangmian\짜장면037.jpg
# [1.9163303e-07 9.9997926e-01 1.7541453e-05 1.0306037e-06 1.9501902e-06]  :  1 jjajiangmian\짜장면038.jpg
# [4.4570686e-04 8.9393032e-01 3.4608308e-04 5.2019089e-02 5.3258836e-02]  :  1 jjajiangmian\짜장면039.jpg
# [3.8778515e-05 9.9973017e-01 8.7948902e-05 1.4188162e-04 1.2578697e-06]  :  1 jjajiangmian\짜장면040.jpg
# [1.3579971e-03 9.9819702e-01 3.2086347e-04 1.0265648e-04 2.1482247e-05]  :  1 jjajiangmian\짜장면041.jpg
# [0.4715598  0.5200285  0.00442135 0.00155734 0.00243309]  :  1 jjajiangmian\짜장면042.jpg
# [9.3957678e-05 9.9964333e-01 1.2822398e-04 6.6376735e-05 6.8206806e-05]  :  1 jjajiangmian\짜장면043.jpg
# [1.2213111e-05 3.6006027e-06 9.9998403e-01 2.3179519e-08 1.3315606e-07]  :  2 kuk-bob\국밥030.jpg
# [8.8524459e-05 1.1397974e-03 9.9625325e-01 4.6512290e-05 2.4717976e-03]  :  2 kuk-bob\국밥031.jpg
# [1.0062411e-04 8.8345725e-04 9.9301600e-01 8.3630966e-06 5.9915171e-03]  :  2 kuk-bob\국밥032.jpg
# [4.2390991e-05 3.5095974e-05 9.9988389e-01 8.6160235e-06 3.0070752e-05]  :  2 kuk-bob\국밥033.jpg
# [0.22339648 0.07601962 0.5977152  0.00222571 0.1006429 ]  :  2 kuk-bob\국밥034.jpg
# [1.2237963e-07 1.0325050e-06 9.9993789e-01 4.0961602e-08 6.0945455e-05]  :  2 kuk-bob\국밥035.jpg
# [1.7643300e-03 4.5841771e-05 9.9806839e-01 9.1443135e-06 1.1232633e-04]  :  2 kuk-bob\국밥036.jpg
# [0.0089449  0.0088664  0.9691705  0.00632468 0.00669347]  :  2 kuk-bob\국밥037.jpg
# [0.00339816 0.3518252  0.49336094 0.08285926 0.06855641]  :  2 kuk-bob\국밥038.jpg
# [2.3035408e-04 1.2933788e-03 9.9742621e-01 4.9749459e-04 5.5259868e-04]  :  2 kuk-bob\국밥039.jpg
# [2.1044938e-04 1.9568310e-03 9.9754566e-01 2.7279884e-05 2.5983658e-04]  :  2 kuk-bob\국밥040.jpg
# [1.7381170e-04 3.8331239e-03 9.3143189e-01 1.8955336e-03 6.2665626e-02]  :  2 kuk-bob\국밥041.jpg
# [2.9262281e-03 4.9370283e-04 9.8122245e-01 9.9081508e-06 1.5347708e-02]  :  2 kuk-bob\국밥042.jpg
# [2.9269268e-04 5.1386510e-03 9.9422270e-01 1.6767022e-04 1.7826560e-04]  :  2 kuk-bob\국밥043.jpg
# [3.1586876e-04 1.1683790e-04 9.9936575e-01 5.3352996e-05 1.4824519e-04]  :  2 kuk-bob\국밥044.jpg
# [0.00339816 0.3518252  0.49336094 0.08285926 0.06855641]  :  2 kuk-bob\국밥051.jpg
# [3.7123248e-02 7.8483745e-03 9.5499641e-01 1.3873914e-06 3.0577183e-05]  :  2 kuk-bob\국밥052.jpg
# [1.2558089e-06 1.4125601e-03 9.9858546e-01 5.7262662e-07 1.7821537e-07]  :  2 kuk-bob\국밥053.jpg
# [6.5352702e-05 1.6180465e-03 9.9829048e-01 1.4388685e-06 2.4696297e-05]  :  2 kuk-bob\국밥054.jpg
# [4.8881851e-04 1.0228488e-03 9.4677210e-01 1.4450770e-05 5.1701821e-02]  :  2 kuk-bob\국밥055.jpg
# [6.9771617e-05 3.2997894e-04 1.0489359e-05 9.9932563e-01 2.6410224e-04]  :  3 bat-soup\Z.jpg
# [3.3486489e-04 6.2914008e-01 2.1149063e-01 2.6722290e-02 1.3231209e-01]  :  3 bat-soup\중국박쥐탕023.jpg
# [0.04345576 0.13415842 0.10401676 0.7164204  0.00194872]  :  3 bat-soup\중국박쥐탕024.jpg
# [0.00191691 0.01071574 0.22439468 0.00371062 0.759262  ]  :  3 bat-soup\중국박쥐탕025.jpg
# [0.12015597 0.36781478 0.20324326 0.11371738 0.19506864]  :  3 bat-soup\중국박쥐탕028.jpg
# [3.6058049e-05 5.5347064e-05 6.4114691e-05 9.9969733e-01 1.4721515e-04]  :  3 bat-soup\중국박쥐탕029.jpg
# [3.5311198e-06 2.0018811e-06 2.3622615e-06 9.9998617e-01 5.9312365e-06]  :  3 bat-soup\중국박쥐탕030.jpg
# [1.1116486e-04 1.0013289e-04 7.9584708e-05 9.9969172e-01 1.7378514e-05]  :  3 bat-soup\중국박쥐탕031.jpg
# [2.7705882e-02 6.6873968e-02 2.3204068e-04 8.9765525e-01 7.5329561e-03]  :  3 bat-soup\중국박쥐탕032.jpg
# [0.7313564  0.12227048 0.01856438 0.11259945 0.01520932]  :  3 bat-soup\중국박쥐탕033.jpg
# [0.00619683 0.00401272 0.07213107 0.3731459  0.5445135 ]  :  3 bat-soup\중국박쥐탕040.jpg
# [1.7117999e-03 8.9156453e-04 4.3904567e-03 9.8310107e-01 9.9050635e-03]  :  3 bat-soup\중국박쥐탕041.jpg
# [6.2723515e-08 1.7077962e-05 7.4090558e-08 9.9996996e-01 1.2738421e-05]  :  3 bat-soup\중국박쥐탕042.jpg
# [0.00920894 0.00569214 0.2147604  0.13634951 0.6339891 ]  :  4 snake-soup\중국식뱀탕003.jpg
# [0.06287057 0.00160067 0.01968852 0.00101973 0.91482055]  :  4 snake-soup\중국식뱀탕031.jpg
# [0.11174728 0.1553036  0.01238627 0.06450018 0.65606266]  :  4 snake-soup\중국식뱀탕032.jpg
# [7.7956166e-08 3.3118104e-04 1.7750230e-05 2.4697115e-07 9.9965072e-01]  :  4 snake-soup\중국식뱀탕033.jpg
# [5.3348722e-06 9.2899963e-06 3.0202702e-05 3.4086395e-05 9.9992108e-01]  :  4 snake-soup\중국식뱀탕034.jpg
# [4.1430836e-04 2.2974861e-04 5.1644904e-04 4.6059717e-03 9.9423355e-01]  :  4 snake-soup\중국식뱀탕035.jpg
# [9.0879112e-06 9.6737790e-01 3.5937664e-03 2.0371696e-03 2.6982002e-02]  :  4 snake-soup\중국식뱀탕036.jpg
# [1.3072160e-04 7.6177761e-02 1.3501053e-03 1.3431319e-03 9.2099839e-01]  :  4 snake-soup\중국식뱀탕037.jpg
# [2.9963943e-05 6.2695122e-05 3.0092422e-06 3.9326321e-04 9.9951100e-01]  :  4 snake-soup\중국식뱀탕038.jpg
# [0.09499367 0.04738218 0.0014199  0.14578214 0.71042216]  :  4 snake-soup\중국식뱀탕039.jpg
# [0.00106643 0.01079693 0.00338883 0.20089328 0.78385454]  :  4 snake-soup\중국식뱀탕040.jpg
# [0.11174728 0.1553036  0.01238627 0.06450018 0.65606266]  :  4 snake-soup\중국식뱀탕041.jpg
# [9.0879112e-06 9.6737790e-01 3.5937664e-03 2.0371696e-03 2.6982002e-02]  :  4 snake-soup\중국식뱀탕045.jpg
# [0.561531   0.39375347 0.00374163 0.01600796 0.024966  ]  :  4 snake-soup\중국식뱀탕046.jpg
# [0.00192121 0.00516564 0.01979837 0.00793068 0.9651841 ]  :  4 snake-soup\중국식뱀탕047.jpg
# [1.1263591e-03 1.0942151e-03 2.0625413e-04 2.9517654e-01 7.0239657e-01]  :  4 snake-soup\중국식뱀탕055.jpg
# [3.6285300e-04 1.5996745e-02 5.2998803e-04 1.0340299e-03 9.8207641e-01]  :  4 snake-soup\중국식뱀탕065.jpg

# %%
cls_index = ['제육볶음', '짜장면', '국밥', '중국식박쥐탕', '중국식뱀탕']
from tensorflow.keras.preprocessing.image import array_to_img
import numpy
imgs = test_generator.next()
#print(imgs)
arr = imgs[0][0]
img = array_to_img(arr).resize((128, 128))
plt.imshow(img)
result = model.predict_classes(arr.reshape(1,150,150,3))
print('예측: {}'.format(cls_index[result[0]]))
#print('정답: {}'.format(cls_index[np.argmax(imgs[1][0])]))
# Out:
# 예측: 제육볶음

# %%
# %matplotlib inline
from tensorflow.keras.models import load_model
model = load_model('HCF_classification_3_0612last.h5')
import numpy as np
import matplotlib.pyplot as plt

#model = load_model('HCF_classification_3_0613_PM4.h5')
model = load_model('HCF_classification_3_0612last.h5')
#imgg='./HCFC/Final_Test/high_caution_food_data/뱀요리47.jpg'
imgg='./Data/Train/3 bat-soup/중국박쥐탕034.jpg'
from tensorflow.keras.preprocessing import image
test_image1 = image.load_img(imgg, target_size = (150,150))
test_image2 = image.img_to_array(test_image1)
test_image2 = np.expand_dims(test_image2, axis = 0)
result = model.predict(test_image2)
print(test_generator.class_indices)
#if result[0][0] >= 0.5:
 #prediction = '저위험군 음식입니다'
#else:
 # prediction = '고위험군 음식입니다'

origin_image = image.load_img(imgg)
plt.imshow(origin_image)
#print('  => predict = ', result[0][0], ', class = ', prediction)
print(result)
# Out:
# {'0 jeyuk-bokkeum': 0, '1 jjajiangmian': 1, '2 kuk-bob': 2, '3 bat-soup': 3, '4 snake-soup': 4}
# [[0.]]
